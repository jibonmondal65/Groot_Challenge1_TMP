# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('retail_data.csv')

# %%
df
# Out:
#         Transaction_ID  Customer_ID                 Name  \
# 0            8691788.0      37249.0  Michelle Harrington
# 1            2174773.0      69749.0          Kelsey Hill
# 2            6679610.0      30192.0         Scott Jensen
# 3            7232460.0      62101.0        Joseph Miller
# 4            4983775.0      27901.0        Debra Coleman
# ...                ...          ...                  ...
# 302005       4246475.0      12104.0         Meagan Ellis
# 302006       1197603.0      69772.0          Mathew Beck
# 302007       7743242.0      28449.0           Daniel Lee
# 302008       9301950.0      45477.0       Patrick Wilson
# 302009       2882826.0      53626.0       Dustin Merritt
#
#                            Email         Phone                       Address  \
# 0              Ebony39@gmail.com  1.414787e+09             3959 Amanda Burgs
# 1               Mark36@gmail.com  6.852900e+09            82072 Dawn Centers
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302010 entries, 0 to 302009
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    301677 non-null  float64
#  1   Customer_ID       301702 non-null  float64
#  2   Name              301628 non-null  object
#  3   Email             301663 non-null  object
#  4   Phone             301648 non-null  float64
#  5   Address           301695 non-null  object
#  6   City              301762 non-null  object
#  7   State             301729 non-null  object
#  8   Zipcode           301670 non-null  float64
#  9   Country           301739 non-null  object
#  10  Age               301837 non-null  float64
#  11  Gender            301693 non-null  object
#  12  Income            301720 non-null  object
#  13  Customer_Segment  301795 non-null  object
#  14  Date              301651 non-null  object
# ...

# %% [markdown]
# Univariate Analysis of Numerical Columns:-

# %% [markdown]
# Univariate Analysis of Age:-

# %%
df['Age']
# Out:
# 0         21.0
# 1         19.0
# 2         48.0
# 3         56.0
# 4         22.0
#           ...
# 302005    31.0
# 302006    35.0
# 302007    41.0
# 302008    41.0
# 302009    28.0
# Name: Age, Length: 302010, dtype: float64

# %%
print(df['Age'].describe())
# Out:
# count    301837.000000
# mean         35.481326
# std          15.021933
# min          18.000000
# 25%          22.000000
# 50%          32.000000
# 75%          46.000000
# max          70.000000
# Name: Age, dtype: float64

# %%
plt.hist(df['Age'], bins=10,edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
def categorize_age(age):
    if age <= 25:
        return 'Young Adults'
    elif age <= 65:
        return 'Working Age'
    else:
        return 'Retirement Age'
df['Age_Group'] = df['Age'].apply(categorize_age)
sns.countplot(x='Age_Group', data=df, palette='Set1')
plt.title('Age Group Distribution')
plt.xlabel('Age Group')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x=df['Age'])
plt.title('Boxplot of Age')
plt.show()

# %% [markdown]
# Univariate Analysis of Total_Purchases:-

# %%
df['Total_Purchases']
# Out:
# 0         3.0
# 1         2.0
# 2         3.0
# 3         7.0
# 4         2.0
#          ...
# 302005    5.0
# 302006    1.0
# 302007    3.0
# 302008    1.0
# 302009    7.0
# Name: Total_Purchases, Length: 302010, dtype: float64

# %%
print(df['Total_Purchases'].describe())
# Out:
# count    301649.000000
# mean          5.359729
# std           2.868575
# min           1.000000
# 25%           3.000000
# 50%           5.000000
# 75%           8.000000
# max          10.000000
# Name: Total_Purchases, dtype: float64

# %%
plt.hist(df['Total_Purchases'], bins=10, edgecolor='black')
plt.title('Distribution of Total Purchases')
plt.xlabel('Total Purchases')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['Total_Purchases'])
plt.title('Boxplot of Total Purchases')
plt.show()

# %% [markdown]
# Univariate Analysis of Amount:-

# %%
print(df['Amount'].describe())
# Out:
# count    301653.000000
# mean        255.163659
# std         141.389640
# min          10.000219
# 25%         132.890764
# 50%         255.470969
# 75%         377.672606
# max         499.997911
# Name: Amount, dtype: float64

# %%
plt.hist(df['Amount'], bins=10, edgecolor='black')
plt.title('Distribution of Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['Amount'])
plt.title('Boxplot of Amount Spent')
plt.show()

# %% [markdown]
# Univariate Analysis of Total_Amount:-

# %%
print(df['Total_Amount'].describe())
# Out:
# count    301660.000000
# mean       1367.651156
# std        1128.998515
# min          10.003750
# 25%         438.724278
# 50%        1041.117547
# 75%        2029.999853
# max        4999.625796
# Name: Total_Amount, dtype: float64

# %%
plt.hist(df['Total_Amount'].dropna(), bins=10, edgecolor='black')
plt.title('Distribution of Total Amount')
plt.xlabel('Total Amount')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['Total_Amount'])
plt.title('Boxplot of Total Amount')
plt.show()

# %% [markdown]
# Univariate Analysis of Ratings:-

# %%
print(df['Ratings'].describe())
# Out:
# count    301826.000000
# mean          3.162670
# std           1.320827
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Ratings, dtype: float64

# %%
df.groupby('Ratings').size()
# Out:
# Ratings
# 1.0    43299
# 2.0    62674
# 3.0    47636
# 4.0    98064
# 5.0    50153
# dtype: int64

# %%
sns.countplot(x='Ratings', data=df, palette='Set1')
plt.title('Distribution of Ratings')
plt.xlabel('Ratings')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Bivariate Analysis:-

# %% [markdown]
# Age vs Total Amount

# %%
sns.barplot(x='Age_Group', y='Total_Amount', data=df)
plt.title('Age vs Total Amount')
plt.show()

# %% [markdown]
# Age vs Ratings

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='Age_Group', y='Ratings', data=df, palette="pastel", ci=None)
plt.title('Average Ratings by Age Group')
plt.ylim(0,5)
plt.xlabel('Age Group')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Age vs Gender

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Gender', y='Age', data=df, palette="pastel")
plt.title('Age Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Gender', data=df, palette="Set1",hue="Age_Group")
plt.title('Order Frequency on basis of Gender and Age Group')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Age vs Income

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Income', y='Age', data=df, palette="Set2")
plt.title('Age Distribution by Income Group')
plt.xlabel('Income')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# Amount and Total_Purchases

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Payment_Method', y='Total_Purchases', data=df, estimator=sum, ci=None, palette="pastel")
plt.title('Total Purchases by Payment Method (Sum)')
plt.xlabel('Payment Method')
plt.ylabel('Total Purchases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Total_Purchases vs Country

# %%
df1=df.groupby('Country')['Total_Purchases'].sum().reset_index()
df1
# Out:
#      Country  Total_Purchases
# 0  Australia         242749.0
# 1     Canada         242178.0
# 2    Germany         282840.0
# 3         UK         338641.0
# 4        USA         508919.0

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Country', y='Total_Purchases', data=df1,ci=None, palette="pastel")
plt.title('Total Purchases by Country (Sum)')
plt.xlabel('Country')
plt.ylabel('Total Purchases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Total_Purchases vs Country

# %%
df2 = df.groupby('City')['Total_Purchases'].sum().reset_index()
df2 = df2.sort_values(by='Total_Purchases', ascending=False).reset_index(drop=True)
print(df2)
# Out:
#               City  Total_Purchases
# 0          Chicago         116082.0
# 1       Portsmouth         108257.0
# 2    San Francisco          64546.0
# 3        Frankfurt          54918.0
# 4           Boston          50459.0
# ..             ...              ...
# 125      Arlington           4623.0
# 126    Kansas City           4532.0
# 127      San Diego           4503.0
# 128   Philadelphia           4483.0
# 129     Washington           4462.0
#
# [130 rows x 2 columns]

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='City', y='Total_Purchases', data=df2.head(30), ci=None, palette="pastel")
plt.title('Total Purchases by City (Sum)')
plt.xlabel('City')
plt.ylabel('Total Purchases')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
df3 = df.groupby('State')['Total_Purchases'].sum().reset_index()
df3 = df3.sort_values(by='Total_Purchases', ascending=False).reset_index(drop=True)
print(df3)
# Out:
#               State  Total_Purchases
# 0           England         338601.0
# 1            Berlin         282796.0
# 2   New South Wales         242742.0
# 3           Ontario         242224.0
# 4       Connecticut         116006.0
# 5             Maine          64800.0
# 6           Georgia          51059.0
# 7            Kansas          29504.0
# 8        New Mexico          28058.0
# 9          New York           5414.0
# 10           Nevada           5248.0
# 11     Pennsylvania           5227.0
# 12            Texas           5211.0
# 13             Iowa           5144.0
# 14         Maryland           5120.0
# 15         Illinois           5115.0
# 16      Mississippi           5105.0
# 17    West Virginia           5090.0
# 18   South Carolina           5026.0
# 19       California           5013.0
# 20        Minnesota           5011.0
# 21             Ohio           4969.0
# 22   North Carolina           4928.0
# 23        Louisiana           4913.0
# ...

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='State', y='Total_Purchases', data=df3.head(30), ci=None, palette="pastel")
plt.title('Total Purchases by State(Sum)')
plt.xlabel('State')
plt.ylabel('Total Purchases')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Ratings vs Customer_Segment

# %%
rating_segment = pd.crosstab(df['Ratings'],df['Customer_Segment'])
print(rating_segment)
# Out:
# Customer_Segment    New  Premium  Regular
# Ratings
# 1.0               12808     6015    24453
# 2.0               18260    11636    32741
# 3.0               14065    10694    22840
# 4.0               30180    23405    44405
# 5.0               15831    12613    21665

# %%
rating_segment.plot(kind='bar', stacked=True, figsize=(10,6), colormap='viridis')

plt.title('Ratings by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Count of Ratings')
plt.xticks(rotation=45)
plt.legend(title='Ratings', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Multivariate Analysis:-

# %% [markdown]
# Customer Segment vs Payment Method for Amount(Median)

# %%
pivot_table = df.pivot_table(values='Amount', index='Customer_Segment', columns='Payment_Method', aggfunc='median')

plt.figure(figsize=(10,6))
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap="YlGnBu")
plt.title('Average Amount by Customer Segment and Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Customer Segment')
plt.tight_layout()
plt.show()

# %% [markdown]
# The heatmap shows that while spending differs across customer segments and payment methods, the variation is slight and the amounts are relatively consistent.

# %% [markdown]
# Age, Amount, and Total_Purchases

# %%
corr = df[['Age', 'Amount', 'Total_Purchases']].corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# 1.Age and Amount → no meaningful relationship
#
# 2.Age and Total_Purchases → very weak positive relationship, but practically negligible
#
# 3.Amount and Total_Purchases → almost no correlation, meaning the number of purchases doesn’t strongly influence how much is spent on average

# %% [markdown]
# Monthly Purchases

# %%
months_order = ["January","February","March","April","May","June","July",
                "August","September","October","November","December"]
df['Month'] = pd.Categorical(df['Month'], categories=months_order, ordered=True)

monthly_trend = df.groupby(['Year','Month']).agg({
    'Total_Purchases':'sum',
    'Total_Amount':'sum'
}).reset_index()

plt.figure(figsize=(14,6))
sns.lineplot(data=monthly_trend, x='Month', y='Total_Purchases', hue='Year',palette="bright", marker='o')
plt.title("Monthly Purchases Trend by Year")
plt.ylabel("Total Purchases")
plt.xlabel("Month")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Year')
plt.tight_layout()
plt.show()

# %% [markdown]
# 2nd ipynb file:-

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302010 entries, 0 to 302009
# Data columns (total 31 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    301677 non-null  float64
#  1   Customer_ID       301702 non-null  float64
#  2   Name              301628 non-null  object
#  3   Email             301663 non-null  object
#  4   Phone             301648 non-null  float64
#  5   Address           301695 non-null  object
#  6   City              301762 non-null  object
#  7   State             301729 non-null  object
#  8   Zipcode           301670 non-null  float64
#  9   Country           301739 non-null  object
#  10  Age               301837 non-null  float64
#  11  Gender            301693 non-null  object
#  12  Income            301720 non-null  object
#  13  Customer_Segment  301795 non-null  object
#  14  Date              301651 non-null  object
# ...

# %%
#numerical
#Transaction_ID,Customer_ID,Phone,Zipcode,Age,Total_Purchases,Amount,Total_Amount,Ratings,income
#temporal
#Date,Year,Month,Time
#categorical
# Time,Email,Address,City,State,

# %% [markdown]
# univariate analysis of numerical dataset

# %%
df['Age'].describe()
# Out:
# count    301837.000000
# mean         35.481326
# std          15.021933
# min          18.000000
# 25%          22.000000
# 50%          32.000000
# 75%          46.000000
# max          70.000000
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Age'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# insight : age group with 18-25 are most active customers

# %%
rd=df.copy()

# %%
rd['Age'].describe()
# Out:
# count    301837.000000
# mean         35.481326
# std          15.021933
# min          18.000000
# 25%          22.000000
# 50%          32.000000
# 75%          46.000000
# max          70.000000
# Name: Age, dtype: float64

# %%
conditions = [
    (rd['Age'] >= 18) & (rd['Age'] < 25),
    (rd['Age'] >=25) & (rd['Age'] < 65),
    rd['Age'] >= 65 &(rd['Age']< 70)
]


choices = ['young adulthood','working age','retirement age']


rd['age_group'] = np.select(conditions, choices,default='')

# %%
rd['age_group']
# Out:
# 0         young adulthood
# 1         young adulthood
# 2             working age
# 3             working age
# 4         young adulthood
#                ...
# 302005        working age
# 302006        working age
# 302007        working age
# 302008        working age
# 302009        working age
# Name: age_group, Length: 302010, dtype: object

# %% [markdown]
# Univariate analysis of categorical data

# %%
rd['Product_Category'].nunique()
# Out:
# 5

# %%
rd_Product_category=rd["Product_Category"].value_counts().reset_index()
rd_Product_category
# Out:
#   Product_Category  count
# 0      Electronics  71196
# 1          Grocery  66786
# 2         Clothing  54741
# 3            Books  54622
# 4       Home Decor  54382

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=rd,x='Product_Category',hue="Product_Category",palette="viridis")
plt.title('product category')
plt.xlabel('product category')
plt.ylabel('Frequency')
plt.legend().set_visible(False)
plt.show()

# %%
dfa=rd["Product_Category"].value_counts().reset_index()
dfa.set_index('Product_Category', inplace=True)

dfa['count'].plot.pie(
    autopct='%1.1f%%',
    figsize=(6, 6),
    startangle=90,
    legend=False,
    )
plt.title('Category Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# Product Category Distribution based on age group ::

# %%
rd_agegroup_pc=rd.groupby('age_group')['Product_Category'].value_counts().reset_index()
rd_agegroup_pc  # there are some null values initially with no age related data
# Out:
#           age_group Product_Category  count
# 0                        Electronics     43
# 1                           Clothing     38
# 2                              Books     32
# 3                            Grocery     31
# 4                         Home Decor     29
# 5    retirement age      Electronics   3985
# 6    retirement age         Clothing   2935
# 7    retirement age          Grocery   2934
# 8    retirement age       Home Decor   2895
# 9    retirement age            Books   2873
# 10      working age      Electronics  44366
# 11      working age          Grocery  42279
# 12      working age         Clothing  30202
# 13      working age            Books  30076
# 14      working age       Home Decor  29818
# 15  young adulthood      Electronics  22802
# 16  young adulthood            Books  21641
# 17  young adulthood       Home Decor  21640
# 18  young adulthood         Clothing  21566
# 19  young adulthood          Grocery  21542

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=rd,x='Product_Category',hue="age_group")
plt.title('product category')
plt.xlabel('product category')
plt.ylabel('Frequency')
plt.legend(title="Age Group")
plt.show()

# %%
rd_gender_pc=rd.groupby('Gender')['Product_Category'].value_counts().reset_index()
rd_gender_pc  # there are some null values initially with no age related data
# Out:
#    Gender Product_Category  count
# 0  Female          Grocery  25893
# 1  Female      Electronics  24679
# 2  Female            Books  21189
# 3  Female         Clothing  21111
# 4  Female       Home Decor  21107
# 5    Male      Electronics  46447
# 6    Male          Grocery  40835
# 7    Male         Clothing  33565
# 8    Male            Books  33379
# 9    Male       Home Decor  33205

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=rd,x='Product_Category',hue="Gender")
plt.title('product category vs gender')
plt.xlabel('product category')
plt.ylabel('Frequency')
plt.legend(title="Gender")
plt.show()

# %% [markdown]
# Customer Segment CountPlot ::

# %%
rd_customer_segment = rd["Customer_Segment"].value_counts().reset_index()
rd_customer_segment
# Out:
#   Customer_Segment   count
# 0          Regular  146221
# 1              New   91187
# 2          Premium   64387

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=rd,x='Customer_Segment', width=0.3)
plt.title('customer segment countplot')
plt.xlabel('customer segment')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# Customer Segmentation ::

# %%
dfb=rd["Customer_Segment"].value_counts().reset_index()
dfb.set_index('Customer_Segment', inplace=True)

dfb['count'].plot.pie(
    autopct='%1.1f%%',
    figsize=(6, 6),
    startangle=90,
    legend=False,
    )
plt.title('Customer Segment Distribution')
plt.ylabel('')
plt.show()

# %%
rd_agegroup_cs=rd.groupby('age_group')['Customer_Segment'].value_counts().reset_index()
rd_agegroup_cs  # there are some null values initially with no age related data
# Out:
#           age_group Customer_Segment  count
# 0                            Regular     64
# 1                            Premium     59
# 2                                New     50
# 3    retirement age          Regular   5993
# 4    retirement age              New   4956
# 5    retirement age          Premium   4665
# 6       working age          Regular  74034
# 7       working age              New  52008
# 8       working age          Premium  50691
# 9   young adulthood          Regular  66130
# 10  young adulthood              New  34173
# 11  young adulthood          Premium   8972

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=rd,x='Customer_Segment',hue="age_group")
plt.title('Customer segment countplot based on age')
plt.xlabel('Customer Segment')
plt.ylabel('Frequency')
plt.legend(title="Age Group")
plt.show()

# %% [markdown]
# Gender and age groups frequency ::

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=rd,x='Gender',hue="age_group")
plt.title('Gender Countplot')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.legend(title="Age Group")
plt.show()

# %% [markdown]
# ----------------------- Payment Method-----------------------------------

# %%
rd['Payment_Method'].nunique()
# Out:
# 4

# %%
rd_payment_method=rd["Payment_Method"].value_counts().reset_index()
rd_payment_method
# Out:
#   Payment_Method  count
# 0    Credit Card  90116
# 1     Debit Card  76790
# 2           Cash  73810
# 3         PayPal  60997

# %% [markdown]
# Payment method univariate analysis

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=rd,x='Payment_Method', width=0.6)
plt.title('Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# Insight : Credit is the most preferable among all payment methods

# %% [markdown]
# Age group wise payment method analysis

# %%
rd_agegroup_pm=rd.groupby('age_group')['Payment_Method'].value_counts().reset_index()
rd_agegroup_pm  # there are some null values initially with no age related data
# Out:
#           age_group Payment_Method  count
# 0                      Credit Card     64
# 1                       Debit Card     43
# 2                             Cash     41
# 3                           PayPal     25
# 4    retirement age    Credit Card   5558
# 5    retirement age     Debit Card   4034
# 6    retirement age           Cash   3697
# 7    retirement age         PayPal   2337
# 8       working age    Credit Card  55092
# 9       working age     Debit Card  45112
# 10      working age           Cash  43187
# 11      working age         PayPal  33329
# 12  young adulthood    Credit Card  29402
# 13  young adulthood     Debit Card  27601
# 14  young adulthood           Cash  26885
# 15  young adulthood         PayPal  25306

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=rd,x='Payment_Method',hue="age_group")
plt.title('Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('Frequency')
plt.legend(title="Age Group")
plt.show()

# %% [markdown]
# ::: Shipping Method analysis :::

# %%
rd['Shipping_Method'].nunique()
# Out:
# 3

# %%
rd1=rd['Shipping_Method'].value_counts().reset_index()

# %% [markdown]
# Type of shipping methods provided by service

# %%
rd1
# Out:
#   Shipping_Method   count
# 0        Same-Day  104156
# 1         Express  102356
# 2        Standard   95161

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=rd1,x='Shipping_Method', y="count",hue="Shipping_Method",width=0.3)
plt.title('Shipping Method')
plt.xlabel('Shipping Method')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# :::: Feedback Analysis ::::

# %%
rd['Feedback'].nunique()
# Out:
# 4

# %%
rd2=rd['Feedback'].value_counts().reset_index()

# %%
rd2
# Out:
#     Feedback   count
# 0  Excellent  100755
# 1       Good   95098
# 2    Average   62674
# 3        Bad   43299

# %% [markdown]
# Feedback Univariate analysis

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=rd2,x='Feedback',y='count',width=0.3)
plt.title('Feedback frequency distribution')
plt.xlabel('Feedback frequency distribution')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# product categorywise feedback analysis

# %%
rd['Product_Category'].unique()
# Out:
# array(['Clothing', 'Electronics', 'Books', 'Home Decor', 'Grocery', nan],
#       dtype=object)

# %% [markdown]
# Selecting Clothing Product Category :

# %%
rd_cg_clothing =rd[rd['Product_Category']=="Clothing"]
rd_cg_clothing['Product_Brand'].nunique()
# Out:
# 3

# %% [markdown]
# Clothing brands :

# %%
rd_cg_clothing_vc=rd_cg_clothing['Product_Brand'].value_counts().reset_index()
rd_cg_clothing_vc
# Out:
#   Product_Brand  count
# 0          Zara  18349
# 1        Adidas  18214
# 2          Nike  18124

# %% [markdown]
# Zara has slightly high no of order frequency compare to other two .

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=rd_cg_clothing_vc,x='Product_Brand',y="count",hue="Product_Brand",width=0.5)
plt.title('Product Brand Sales Frequency')
plt.xlabel('Product Brand')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=rd_cg_clothing,x='Product_Brand',hue="age_group",width=0.5)
plt.title('Product Brand Sales Frequency Among Different Age Groups')
plt.xlabel('Product Brand')
plt.ylabel('Frequency')
plt.show()

# %%
rd_cg_clothing_fb = rd_cg_clothing.groupby('Product_Brand')['Feedback'].value_counts().reset_index()
rd_cg_clothing_fb
# Out:
#    Product_Brand   Feedback  count
# 0         Adidas  Excellent   6377
# 1         Adidas       Good   4760
# 2         Adidas    Average   4089
# 3         Adidas        Bad   2976
# 4           Nike  Excellent   6425
# 5           Nike       Good   4690
# 6           Nike    Average   4078
# 7           Nike        Bad   2917
# 8           Zara  Excellent   6365
# 9           Zara       Good   4771
# 10          Zara    Average   4293
# 11          Zara        Bad   2911

# %% [markdown]
# Product brands and their feedbacks

# %%
plt.figure(figsize=(10, 5))
sns.barplot(data=rd_cg_clothing_fb,x='Feedback',y="count",hue="Product_Brand")
plt.title('Feedback of brands')
plt.xlabel('Feedback')
plt.ylabel('Frequency')
plt.legend(title="Product Brand")
plt.show()

# %% [markdown]
# Selecting Electronics Products :

# %%
rd_cg_electronics =rd[rd['Product_Category']=="Electronics"]
rd_cg_electronics['Product_Brand'].nunique()
# Out:
# 6

# %%
rd_cg_electronics['Product_Type'].nunique()
# Out:
# 8

# %%
rd_cg_electronics_vc=rd_cg_electronics['Product_Brand'].value_counts().reset_index()
rd_cg_electronics_vc
# Out:
#   Product_Brand  count
# 0       Samsung  18358
# 1          Sony  18307
# 2         Apple  18057
# 3     Whirepool   7445
# 4    Mitsubhisi   6724
# 5      BlueStar   2256

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=rd_cg_electronics_vc,x='Product_Brand',y="count",hue="Product_Brand",width=0.5)
plt.title('Electronics Product Brands and Order Frequency')
plt.xlabel('Product Brand')
plt.ylabel('Frequency')
plt.show()

# %%
rd_cg_electronics_fb = rd_cg_electronics.groupby('Product_Brand')['Feedback'].value_counts().reset_index()
rd_cg_electronics_fb
# Out:
#    Product_Brand   Feedback  count
# 0          Apple  Excellent   6353
# 1          Apple       Good   4692
# 2          Apple    Average   4111
# 3          Apple        Bad   2889
# 4       BlueStar  Excellent   2030
# 5       BlueStar       Good    226
# 6     Mitsubhisi       Good   4171
# 7     Mitsubhisi  Excellent   2553
# 8        Samsung  Excellent   6569
# 9        Samsung       Good   4774
# 10       Samsung    Average   4177
# 11       Samsung        Bad   2818
# 12          Sony  Excellent   6498
# 13          Sony       Good   4762
# 14          Sony    Average   4128
# 15          Sony        Bad   2908
# 16     Whirepool       Good   7292
# 17     Whirepool    Average    149
# 18     Whirepool  Excellent      3
# 19     Whirepool        Bad      1

# %%
plt.figure(figsize=(15, 5))
sns.barplot(data=rd_cg_electronics_fb,x='Feedback',y="count",hue="Product_Brand",palette="colorblind")
plt.title('Feedback of Electronic Brands')
plt.xlabel('Feedback')
plt.ylabel('Frequency')
plt.legend(title="Product Brand")
plt.show()

# %%
rd_cg_electronics['Product_Type'].unique()
# Out:
# array(['Tablet', 'Television', 'Smartphone', 'Laptop', 'Headphones',
#        'Fridge', 'Mitsubishi 1.5 Ton 3 Star Split AC', 'BlueStar AC'],
#       dtype=object)

# %%
rd_cg_electronics_sp =rd_cg_electronics[rd_cg_electronics['Product_Type']=='Smartphone']

# %%
c=rd_cg_electronics_sp['Product_Brand'].value_counts().reset_index()
c
# Out:
#   Product_Brand  count
# 0          Sony   6194
# 1       Samsung   6180
# 2         Apple   6065

# %%
rd_cg_electronics_sp_fd =rd_cg_electronics_sp.groupby('Product_Brand')['Feedback'].value_counts().reset_index()
rd_cg_electronics_sp_fd
# Out:
#    Product_Brand   Feedback  count
# 0          Apple  Excellent   2159
# 1          Apple       Good   1594
# 2          Apple    Average   1334
# 3          Apple        Bad    973
# 4        Samsung  Excellent   2197
# 5        Samsung       Good   1595
# 6        Samsung    Average   1453
# 7        Samsung        Bad    928
# 8           Sony  Excellent   2226
# 9           Sony       Good   1578
# 10          Sony    Average   1404
# 11          Sony        Bad    982

# %%
plt.figure(figsize=(15, 5))
sns.barplot(data= rd_cg_electronics_sp_fd,x='Feedback',y="count",hue="Product_Brand",palette="colorblind")
plt.title('Feedback for smartphone brands')
plt.xlabel('Feedback')
plt.ylabel('Frequency')
plt.legend(title="Product Brand")
plt.show()

# %%
rd_cg_electronics_tv =rd_cg_electronics[rd_cg_electronics['Product_Type']=='Television']

# %%
d=rd_cg_electronics_tv['Product_Brand'].value_counts().reset_index()
d
# Out:
#   Product_Brand  count
# 0       Samsung   6130
# 1          Sony   6042

# %%
rd_cg_electronics_tl =rd_cg_electronics[rd_cg_electronics['Product_Type']=='Tablet']

# %%
e=rd_cg_electronics_tl['Product_Brand'].value_counts().reset_index()
e
# Out:
#   Product_Brand  count
# 0       Samsung   6048
# 1         Apple   6023

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=rd_cg_electronics_tv,x='Product_Brand',hue="Product_Brand")
plt.title('product brands for television')
plt.xlabel('product brands for television')
plt.ylabel('Frequency')
plt.legend().set_visible(False)
plt.show()

# %%
rd_cg_homedecor =rd[rd['Product_Category']=="Home Decor"]
rd_cg_homedecor['Product_Brand'].nunique()
# Out:
# 3

# %%
dfc = rd_cg_homedecor.groupby("Product_Brand")["Total_Purchases"].sum().reset_index()
dfc
# Out:
#        Product_Brand  Total_Purchases
# 0  Bed Bath & Beyond          97273.0
# 1         Home Depot          97199.0
# 2               IKEA          96235.0

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=dfc,x='Product_Brand',y="Total_Purchases",hue="Product_Brand",width=0.5)
plt.title('Product Brand Purchases')
plt.xlabel('Product Brand')
plt.ylabel('Total Purchases')
plt.show()

# %%
rd_cg_homedecor_vc=rd_cg_homedecor['Product_Brand'].value_counts().reset_index()
rd_cg_homedecor_vc
# Out:
#        Product_Brand  count
# 0  Bed Bath & Beyond  18225
# 1         Home Depot  18127
# 2               IKEA  17978

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=rd_cg_homedecor_vc,x='Product_Brand',y="count",hue="Product_Brand",width=0.5)
plt.title('Product Brand  Frequency')
plt.xlabel('Product Brand')
plt.ylabel('Frequency')
plt.show()

# %%
rd_cg_homedecor_fb = rd_cg_homedecor.groupby('Product_Brand')['Feedback'].value_counts().reset_index()
rd_cg_homedecor_fb
# Out:
#         Product_Brand   Feedback  count
# 0   Bed Bath & Beyond  Excellent   6430
# 1   Bed Bath & Beyond       Good   4724
# 2   Bed Bath & Beyond    Average   4201
# 3   Bed Bath & Beyond        Bad   2859
# 4          Home Depot  Excellent   6322
# 5          Home Depot       Good   4709
# 6          Home Depot    Average   4193
# 7          Home Depot        Bad   2890
# 8                IKEA  Excellent   6215
# 9                IKEA       Good   4859
# 10               IKEA    Average   4087
# 11               IKEA        Bad   2802

# %%
plt.figure(figsize=(15, 5))
sns.barplot(data=rd_cg_homedecor_fb,x='Feedback',y="count",hue="Product_Brand",palette="colorblind")
plt.title('Feedback with brands')
plt.xlabel('Feedback')
plt.ylabel('Frequency')
plt.legend(title="Product Brand")
plt.show()

# %%
rd_cg_books = rd[rd['Product_Category']=="Books"]

# %%
rd_cg_books["Product_Type"].unique()
# Out:
# array(["Children's", 'Non-Fiction', 'Literature', 'Thriller', 'Fiction'],
#       dtype=object)

# %%
h = rd_cg_books["Product_Type"].value_counts().reset_index()
h
# Out:
#   Product_Type  count
# 0  Non-Fiction  18148
# 1      Fiction  18028
# 2     Thriller   6258
# 3   Children's   6143
# 4   Literature   6045

# %%
plt.figure(figsize=(10, 5))
sns.barplot(data=h,x='Product_Type',y="count",hue="Product_Type")
plt.title('Book Type and Frequency')
plt.xlabel('Book Type')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=rd_cg_books,x='Product_Type',hue="age_group")
plt.title('Book Type Frequency & Customer Age-group wise Division')
plt.xlabel('Book Type')
plt.ylabel('Frequency')
plt.legend(title="Age Group")
plt.show()

# %%
rd_cg_grocery = rd[rd["Product_Category"]=="Grocery"]
rd_cg_grocery
# Out:
#         Transaction_ID  Customer_ID                 Name                Email  \
# 4            4983775.0      27901.0        Debra Coleman  Charles30@gmail.com
# 8            4155845.0      80175.0          Diane Clark   Martin39@gmail.com
# 12           2846832.0      31930.0    Kristine Williams  Charles29@gmail.com
# 13           3217461.0      74671.0        Felicia Brown    Laura72@gmail.com
# 16           6681000.0      69939.0     Jessica Harrison     Anne45@gmail.com
# ...                ...          ...                  ...                  ...
# 301986       1648101.0      53653.0          Jill Torres    Tyler34@gmail.com
# 301987       4957231.0      85053.0      Alexandra Brown   Leslie14@gmail.com
# 301990       3020146.0      35103.0  Christina Gutierrez   Edward62@gmail.com
# 301994       5346939.0      12465.0        Daniel Miller  Kaitlin85@gmail.com
# 302000       9862022.0      99656.0         Amber Fields   Donald38@gmail.com
#
# ...

# %%
rd_cg_grocery["Product_Type"].unique()
# Out:
# array(['Chocolate', 'Water', 'Snacks', 'Juice', 'Coffee', 'Soft Drink'],
#       dtype=object)

# %%
k=rd_cg_grocery["Product_Type"].value_counts().reset_index()
k
# Out:
#   Product_Type  count
# 0        Water  24451
# 1        Juice  12208
# 2   Soft Drink  12024
# 3       Coffee   6171
# 4    Chocolate   6041
# 5       Snacks   5891

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=rd_cg_grocery,x='Product_Type',hue="Product_Type")
plt.title('Product Type')
plt.xlabel('Product Type')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=rd_cg_grocery,x='Product_Type',hue="Shipping_Method")
plt.title('Product Type')
plt.xlabel('Product Type')
plt.ylabel('Frequency')
plt.legend(title="Age Group")
plt.show()

# %% [markdown]
# :::::income related :::::::

# %%
rd_low_income = rd[rd["Income"]=="Low"]
rd_medium_income = rd[rd["Income"]=="Medium"]
rd_high_income = rd[rd["Income"]=="High"]

# %%
rd_low_income["Total_Amount"].describe()
# Out:
# count    96142.000000
# mean      1370.943433
# std       1127.374538
# min         10.068154
# 25%        443.896582
# 50%       1047.962265
# 75%       2035.992520
# max       4999.171428
# Name: Total_Amount, dtype: float64

# %%
rd_medium_income["Total_Amount"].describe()
# Out:
# count    130074.000000
# mean       1369.013646
# std        1133.490045
# min          10.092966
# 25%         435.834430
# 50%        1039.579736
# 75%        2033.590122
# max        4999.625796
# Name: Total_Amount, dtype: float64

# %%
rd_high_income["Total_Amount"].describe()
# Out:
# count    75154.000000
# mean      1361.073963
# std       1123.211833
# min         10.003750
# 25%        437.134041
# 50%       1035.905312
# 75%       2016.747718
# max       4998.723479
# Name: Total_Amount, dtype: float64

# %%
rd["Amount"].describe()
# Out:
# count    301653.000000
# mean        255.163659
# std         141.389640
# min          10.000219
# 25%         132.890764
# 50%         255.470969
# 75%         377.672606
# max         499.997911
# Name: Amount, dtype: float64

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Income', y='Total_Amount', data=rd,hue="Income")

plt.title('Income vs Total Amount')
plt.xlabel('Income Category')
plt.ylabel('Amount')

plt.show()

# %% [markdown]
# Analysing sales :

# %%
dfa=rd.copy()
dfa["Time"]
# Out:
# 0         22:03:55
# 1          8:42:04
# 2          4:06:29
# 3         14:55:17
# 4         16:54:07
#             ...
# 302005    23:40:29
# 302006     2:55:45
# 302007     2:43:49
# 302008    11:20:31
# 302009    11:44:36
# Name: Time, Length: 302010, dtype: object

# %%
dfa["Time_hour"]=dfa["Time"].str.split(":").str[0].fillna(0).astype(int) #getting the hour value from the time and converting type int

# %%
dfa["Time_hour"]
# Out:
# 0         22
# 1          8
# 2          4
# 3         14
# 4         16
#           ..
# 302005    23
# 302006     2
# 302007     2
# 302008    11
# 302009    11
# Name: Time_hour, Length: 302010, dtype: int64

# %%
choices = ["Early Morning","Working Hour","Evening Hour","Late Night"]
conditions=[
    (dfa["Time_hour"]>=5) & (dfa["Time_hour"]<9),
    (dfa["Time_hour"]>=9) & (dfa["Time_hour"]<17),
    (dfa["Time_hour"]>=17) & (dfa["Time_hour"]<23),
    (dfa["Time_hour"]>=0) & (dfa["Time_hour"]<5)
]
dfa["Day_segment"] = np.select(conditions,choices,default="Working Hour") # here for some data are missing and we are keeping working hour as default
dfa["Day_segment"]
# Out:
# 0          Evening Hour
# 1         Early Morning
# 2            Late Night
# 3          Working Hour
# 4          Working Hour
#               ...
# 302005     Working Hour
# 302006       Late Night
# 302007       Late Night
# 302008     Working Hour
# 302009     Working Hour
# Name: Day_segment, Length: 302010, dtype: object

# %%
dfb =dfa["Day_segment"].value_counts().reset_index()
dfb
# Out:
#      Day_segment   count
# 0   Working Hour  113081
# 1   Evening Hour   75681
# 2     Late Night   62801
# 3  Early Morning   50447

# %%
plt.figure(figsize=(10, 5))
sns.barplot(data=dfb,x='Day_segment',y="count",hue="Day_segment",palette="plasma",edgecolor="black")
plt.title('Frequency of ordering')
plt.xlabel('Time segments')
plt.ylabel('Frequency')
plt.show()

# %%
dfc=dfa.groupby("Day_segment")["Total_Purchases"].sum().sort_values(ascending=False).reset_index()
dfc
# Out:
#      Day_segment  Total_Purchases
# 0   Working Hour         606700.0
# 1   Evening Hour         405376.0
# 2     Late Night         335178.0
# 3  Early Morning         269503.0

# %%
dfa_1=dfa.groupby(['Day_segment','Product_Category'])['Total_Purchases'].sum().reset_index()
dfa_1
# Out:
#       Day_segment Product_Category  Total_Purchases
# 0   Early Morning            Books          48802.0
# 1   Early Morning         Clothing          48829.0
# 2   Early Morning      Electronics          63379.0
# 3   Early Morning          Grocery          59711.0
# 4   Early Morning       Home Decor          48487.0
# 5    Evening Hour            Books          73707.0
# 6    Evening Hour         Clothing          73700.0
# 7    Evening Hour      Electronics          95522.0
# 8    Evening Hour          Grocery          89883.0
# 9    Evening Hour       Home Decor          72184.0
# 10     Late Night            Books          59545.0
# 11     Late Night         Clothing          61714.0
# 12     Late Night      Electronics          79632.0
# 13     Late Night          Grocery          73827.0
# 14     Late Night       Home Decor          60197.0
# 15   Working Hour            Books         110021.0
# 16   Working Hour         Clothing         109286.0
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=dfa,x='Day_segment',hue="Product_Category",palette="plasma")
plt.title('Frequency Over Day Times of Different Product Category')
plt.xlabel('Day Segment')
plt.ylabel('Frequency')
plt.legend(title="Product Category")
plt.show()

# %% [markdown]
# ## ................................**Customer conversion rate in year 2023**............................

# %%
rd_2023=rd[rd["Year"]==2023.0]

rd_2023_new = rd_2023[rd_2023["Customer_Segment"]=="New"].reset_index(drop=True)
rd1=rd_2023_new[["Customer_Segment","Customer_ID"]].copy()

rd_2023_regular=rd_2023[rd_2023["Customer_Segment"]=="Regular"].reset_index(drop=True)
rd2=rd_2023_regular[["Customer_Segment","Customer_ID"]].copy()

rd_2023_premium=rd_2023[rd_2023["Customer_Segment"]=="Premium"].reset_index(drop=True)
rd3=rd_2023_premium[["Customer_Segment","Customer_ID"]].copy()

# %% [markdown]
# **Customers who are new in customer segment for year 2023 :**

# %%
rd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76031 entries, 0 to 76030
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_Segment  76031 non-null  object
#  1   Customer_ID       75951 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.2+ MB

# %% [markdown]
# **Customers who are regular in customer segment for 2023 :**

# %%
rd2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121962 entries, 0 to 121961
# Data columns (total 2 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Customer_Segment  121962 non-null  object
#  1   Customer_ID       121848 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# **Customers who are premium in customer segment for year 2023 :**

# %%
rd3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53686 entries, 0 to 53685
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_Segment  53686 non-null  object
#  1   Customer_ID       53628 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 839.0+ KB

# %% [markdown]
# Merging dataframes

# %%
#deleting duplicates customer id :
rd1_unique = rd1.drop_duplicates(subset='Customer_ID')
rd2_unique = rd2.drop_duplicates(subset='Customer_ID')
rd3_unique= rd3.drop_duplicates(subset="Customer_ID")

#merging two dataframes for getting the common customers among new and regular one.So we can say they turn into regular from new later
rd_merge_2023_new_regular = pd.merge(rd1_unique, rd2_unique, on="Customer_ID", how='inner')
rd_merge_2023_new_premium = pd.merge(rd1_unique, rd3_unique, on="Customer_ID", how='inner')
rd_merge_2023_regular_premium = pd.merge(rd2_unique, rd3_unique, on="Customer_ID", how='inner')

# %%
print("New to Regular")
print(rd_merge_2023_new_regular.info())
print("//////////////////////////")
print("regular to premium")
print(rd_merge_2023_regular_premium.info())
print("//////////////////////////")
print("new to premium")
print(rd_merge_2023_new_premium.info())
# Out:
# New to Regular
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37950 entries, 0 to 37949
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_Segment_x  37950 non-null  object
#  1   Customer_ID         37949 non-null  float64
#  2   Customer_Segment_y  37950 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 889.6+ KB
# None
# //////////////////////////
# regular to premium
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29701 entries, 0 to 29700
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_Segment_x  29701 non-null  object
#  1   Customer_ID         29700 non-null  float64
#  2   Customer_Segment_y  29701 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 696.2+ KB
# None
# //////////////////////////
# new to premium
# ...

# %% [markdown]
# Conversion rate calculation :

# %%
print( f"new to regular conversion rate {(37950 /76031)*100} %" )
# hence we can say that in year 2023 coversion rate among customer is => 49.91 %
print( f"new to premium conversion rate {( 29701/76031)*100} %" )
# hence we can say that in year 2023 coversion rate among customer is => 39.06 %
print( f"regular to premium conversion rate {(37950 /121962)*100} %" )
# hence we can say that in year 2023 coversion rate among customer is => 31.11%
# Out:
# new to regular conversion rate 49.913850929226236 %
# new to premium conversion rate 39.064329023687705 %
# regular to premium conversion rate 31.116249323559796 %

# %%
data1 = {
    'Conversion_Type':['New->Regular','New->Premium','Regular->Premium'],
    'Conversion_Rate': [49.91,39.06,31.11]
    }
rd_conversion_2023 = pd.DataFrame(data1)
rd_conversion_2023
# Out:
#     Conversion_Type  Conversion_Rate
# 0      New->Regular            49.91
# 1      New->Premium            39.06
# 2  Regular->Premium            31.11

# %%
plt.figure(figsize=(10, 5))
sns.barplot(data=rd_conversion_2023,x='Conversion_Type',y="Conversion_Rate",hue="Conversion_Type",palette="viridis",edgecolor="black")
plt.title('2023 customer conversion rate')
plt.xlabel('Conversion Type')
plt.ylabel('Conversion Rate (percentage)')
plt.show()

# %% [markdown]
# ## ................................**Customer conversion rate in year 2024**............................

# %%
rd_2024=rd[rd["Year"]==2024.0]

rd_2024_new = rd_2024[rd_2024["Customer_Segment"]=="New"].reset_index(drop=True)
rd4=rd_2024_new[["Customer_Segment","Customer_ID"]].copy()

rd_2024_regular=rd_2024[rd_2024["Customer_Segment"]=="Regular"].reset_index(drop=True)
rd5=rd_2024_regular[["Customer_Segment","Customer_ID"]].copy()

rd_2024_premium=rd_2024[rd_2024["Customer_Segment"]=="Premium"].reset_index(drop=True)
rd6=rd_2024_premium[["Customer_Segment","Customer_ID"]].copy()

# %% [markdown]
# **Customers who are new customers in customer segment year 2024**

# %%
rd4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15041 entries, 0 to 15040
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_Segment  15041 non-null  object
#  1   Customer_ID       15026 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 235.1+ KB

# %% [markdown]
# **Customers who are regular customer in customer segment year 2024**

# %%
rd5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24097 entries, 0 to 24096
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_Segment  24097 non-null  object
#  1   Customer_ID       24065 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 376.6+ KB

# %% [markdown]
# **Customer Who are premium customer in customer segment year 2024**

# %%
rd6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10628 entries, 0 to 10627
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_Segment  10628 non-null  object
#  1   Customer_ID       10619 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 166.2+ KB

# %% [markdown]
# Merging dataframes:

# %%
#deleting duplicates customer id :
rd4_unique = rd4.drop_duplicates(subset='Customer_ID')
rd5_unique = rd5.drop_duplicates(subset='Customer_ID')
rd6_unique = rd6.drop_duplicates(subset='Customer_ID')


#merging two dataframes for getting the common customers among new and regular one.So we can observe who turn into regular from new later
rd_merge_2024_new_regular = pd.merge(rd4_unique, rd5_unique, on="Customer_ID", how='inner')
#merging two dataframes for getting the common customers among new and regular one.So we can observe who turn into regular from new later
rd_merge_2024_new_premium = pd.merge(rd4_unique, rd6_unique, on="Customer_ID", how='inner')
rd_merge_2024_regular_premium = pd.merge(rd5_unique, rd6_unique, on="Customer_ID", how='inner')

# %%
print("New to Regular")
print(rd_merge_2024_new_regular.info())
print("//////////////////////////")
print("regular to premium")
print(rd_merge_2024_regular_premium.info())
print("//////////////////////////")
print("new to premium")
print(rd_merge_2024_new_premium.info())
# Out:
# New to Regular
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_Segment_x  3220 non-null   object
#  1   Customer_ID         3219 non-null   float64
#  2   Customer_Segment_y  3220 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 75.6+ KB
# None
# //////////////////////////
# regular to premium
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2332 entries, 0 to 2331
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_Segment_x  2332 non-null   object
#  1   Customer_ID         2331 non-null   float64
#  2   Customer_Segment_y  2332 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 54.8+ KB
# None
# //////////////////////////
# new to premium
# ...

# %% [markdown]
# **Conversion rate conversion calculation :**

# %%
print( f"new to regular conversion rate {(3220/15041)*100 } %" )# hence we can say that in year 2023 coversion rate among customer is => 21.41%
print( f"new to premium conversion rate {( 1498/15041)*100} %" )# hence we can say that in year 2023 coversion rate among customer is => 9.96 %
print( f"regular to premium conversion rate {(2332 /24097)*100} %" )# hence we can say that in year 2023 coversion rate among customer is => 9.68 %
# Out:
# new to regular conversion rate 21.408151053786316 %
# new to premium conversion rate 9.959444185891895 %
# regular to premium conversion rate 9.67755322239283 %

# %%
data2 = {
    'Conversion_Type':['New->Regular','New->Premium','Regular->Premium'],
    'Conversion_Rate': [21.41,9.96,9.68]
    }
rd_conversion_2024= pd.DataFrame(data2)
rd_conversion_2024
# Out:
#     Conversion_Type  Conversion_Rate
# 0      New->Regular            21.41
# 1      New->Premium             9.96
# 2  Regular->Premium             9.68

# %%
plt.figure(figsize=(10, 5))
sns.barplot(data=rd_conversion_2024,x='Conversion_Type',y="Conversion_Rate",hue="Conversion_Type",palette="viridis",edgecolor="black")
plt.title('2024 customer conversion rate')
plt.xlabel('Conversion Type')
plt.ylabel('Conversion Rate (percentage)')
plt.show()
